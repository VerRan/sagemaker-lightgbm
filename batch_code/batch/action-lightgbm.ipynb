# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import io
import os
import sys
import time
import json
from IPython.display import display
from time import strftime, gmtime
import boto3
import re

# !{sys.executable} -m pip install sagemaker -U
# !{sys.executable} -m pip install sagemaker-experiments

import sagemaker
from sagemaker.sklearn import SKLearn
from sagemaker import get_execution_role
from sagemaker.local import LocalSession
from sagemaker.predictor import csv_serializer
from sagemaker.debugger import rule_configs, Rule, DebuggerHookConfig
from sagemaker.model_monitor import DataCaptureConfig, DatasetFormat, DefaultModelMonitor
from sagemaker.s3 import S3Uploader, S3Downloader

from smexperiments.experiment import Experiment
from smexperiments.trial import Trial
from smexperiments.trial_component import TrialComponent
from smexperiments.tracker import Tracker
# Out:
# Requirement already satisfied: sagemaker in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (2.59.5)
# Collecting sagemaker
#   Downloading sagemaker-2.66.1.tar.gz (450 kB)
#      |████████████████████████████████| 450 kB 23 kB/s eta 0:00:013
# Requirement already satisfied: attrs in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (20.3.0)
# Requirement already satisfied: boto3>=1.16.32 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (1.17.76)
# Requirement already satisfied: google-pasta in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (0.2.0)
# Requirement already satisfied: numpy>=1.9.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (1.19.5)
# Requirement already satisfied: protobuf>=3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (3.15.2)
# Requirement already satisfied: protobuf3-to-dict>=0.1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (0.1.5)
# Requirement already satisfied: smdebug_rulesconfig==1.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (1.0.1)
# Requirement already satisfied: importlib-metadata>=1.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (3.7.0)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (20.9)
# Requirement already satisfied: pandas in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (1.1.5)
# Requirement already satisfied: pathos in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (0.2.7)
# Requirement already satisfied: s3transfer<0.5.0,>=0.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3>=1.16.32->sagemaker) (0.4.2)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3>=1.16.32->sagemaker) (0.10.0)
# Requirement already satisfied: botocore<1.21.0,>=1.20.76 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3>=1.16.32->sagemaker) (1.20.76)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore<1.21.0,>=1.20.76->boto3>=1.16.32->sagemaker) (1.26.4)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore<1.21.0,>=1.20.76->boto3>=1.16.32->sagemaker) (2.8.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from importlib-metadata>=1.4.0->sagemaker) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from importlib-metadata>=1.4.0->sagemaker) (3.4.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from packaging>=20.0->sagemaker) (2.4.7)
# Requirement already satisfied: six>=1.9 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from protobuf>=3.1->sagemaker) (1.15.0)
# Requirement already satisfied: pytz>=2017.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandas->sagemaker) (2021.1)
# Requirement already satisfied: dill>=0.3.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pathos->sagemaker) (0.3.3)
# Requirement already satisfied: ppft>=1.6.6.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pathos->sagemaker) (1.6.6.3)
# Requirement already satisfied: pox>=0.2.9 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pathos->sagemaker) (0.2.9)
# Requirement already satisfied: multiprocess>=0.70.11 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pathos->sagemaker) (0.70.11.1)
# Building wheels for collected packages: sagemaker
#   Building wheel for sagemaker (setup.py) ... done
#   Created wheel for sagemaker: filename=sagemaker-2.66.1-py2.py3-none-any.whl size=624253 sha256=9ba29e0d1b3bd5aa514650ed6c4457cd6e71e6be4b78c3010d0bc3e118f4377a
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/76/e2/c5/05eca6d01d7b18bb49b111b63c6692debfea4c5cc4191542ff
# Successfully built sagemaker
# Installing collected packages: sagemaker
#   Attempting uninstall: sagemaker
#     Found existing installation: sagemaker 2.59.5
#     Uninstalling sagemaker-2.59.5:
#       Successfully uninstalled sagemaker-2.59.5
# Successfully installed sagemaker-2.66.1
# Requirement already satisfied: sagemaker-experiments in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (0.1.35)
# Requirement already satisfied: boto3>=1.16.27 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker-experiments) (1.17.76)
# Requirement already satisfied: botocore<1.21.0,>=1.20.76 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3>=1.16.27->sagemaker-experiments) (1.20.76)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3>=1.16.27->sagemaker-experiments) (0.10.0)
# Requirement already satisfied: s3transfer<0.5.0,>=0.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3>=1.16.27->sagemaker-experiments) (0.4.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore<1.21.0,>=1.20.76->boto3>=1.16.27->sagemaker-experiments) (1.26.4)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore<1.21.0,>=1.20.76->boto3>=1.16.27->sagemaker-experiments) (2.8.1)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.21.0,>=1.20.76->boto3>=1.16.27->sagemaker-experiments) (1.15.0)

# %% [markdown]
# ### 打包和部署镜像

# %%
# %%time
# !aws ecr get-login-password --region cn-northwest-1 | docker login --username AWS --password-stdin 451049120500.dkr.ecr.cn-northwest-1.amazonaws.com.cn
# !bash build_push.sh
# Out:
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
# Sending build context to Docker daemon  3.459MB
# Step 1/3 : FROM 451049120500.dkr.ecr.cn-northwest-1.amazonaws.com.cn/sagemaker-scikit-learn:0.20.0-cpu-py3
#  ---> 6c10beb91746
# Step 2/3 : COPY requirements.txt /requirements.txt
#  ---> Using cache
#  ---> c3059de34c94
# Step 3/3 : RUN pip install --no-cache -r /requirements.txt -i https://pypi.douban.com/simple &&     rm /requirements.txt
#  ---> Running in fabcd9b9c016
# Looking in indexes: https://pypi.douban.com/simple
# Collecting lightgbm
#   Downloading https://pypi.doubanio.com/packages/18/b2/fff8370f48549ce223f929fe8cab4ee6bf285a41f86037d91312b48ed95b/lightgbm-3.2.1-py3-none-manylinux1_x86_64.whl (2.0 MB)
# Collecting joblib
#   Downloading https://pypi.doubanio.com/packages/55/85/70c6602b078bd9e6f3da4f467047e906525c355a4dacd4f71b97a35d9897/joblib-1.0.1-py3-none-any.whl (303 kB)
# Collecting shap
#   Downloading https://pypi.doubanio.com/packages/b9/f4/c5b95cddae15be80f8e58b25edceca105aa83c0b8c86a1edad24a6af80d3/shap-0.39.0.tar.gz (356 kB)
# Collecting bokeh
#   Downloading https://pypi.doubanio.com/packages/40/85/9c8c47dc99671590e21d0cecf5cf1208db0ddb525093b2fecdbb233e3645/bokeh-2.3.3.tar.gz (10.7 MB)
# Requirement already satisfied: boto3 in /miniconda3/lib/python3.7/site-packages (from -r /requirements.txt (line 5)) (1.17.36)
# Collecting docker
#   Downloading https://pypi.doubanio.com/packages/b2/5a/f988909dfed18c1ac42ad8d9e611e6c5657e270aa6eb68559985dbb69c13/docker-5.0.0-py2.py3-none-any.whl (146 kB)
# Requirement already satisfied: jinja2 in /miniconda3/lib/python3.7/site-packages (from -r /requirements.txt (line 7)) (2.11.3)
# Collecting jsonschema
#   Downloading https://pypi.doubanio.com/packages/c5/8f/51e89ce52a085483359217bc72cdbf6e75ee595d5b1d4b5ade40c7e018b8/jsonschema-3.2.0-py2.py3-none-any.whl (56 kB)
# Requirement already satisfied: numpy in /miniconda3/lib/python3.7/site-packages (from -r /requirements.txt (line 9)) (1.20.1)
# Requirement already satisfied: pandas in /miniconda3/lib/python3.7/site-packages (from -r /requirements.txt (line 10)) (0.25.3)
# Collecting sagemaker
#   Downloading https://pypi.doubanio.com/packages/66/50/65bdef728ca838eefcc570a80996c2e400febec515d38787afd5fe7f0f8b/sagemaker-2.53.0.tar.gz (438 kB)
# Collecting PyYAML>=3.10
#   Downloading https://pypi.doubanio.com/packages/7a/a5/393c087efdc78091afa2af9f1378762f9821c9c1d7a22c5753fb5ac5f97a/PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
# Requirement already satisfied: python-dateutil>=2.1 in /miniconda3/lib/python3.7/site-packages (from bokeh->-r /requirements.txt (line 4)) (2.8.1)
# Collecting pillow>=7.1.0
#   Downloading https://pypi.doubanio.com/packages/8e/7a/b047f6f80fdb02c0cca1d3761d71e9800bcf6d4874b71c9e6548ec59e156/Pillow-8.3.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (3.0 MB)
# Collecting packaging>=16.8
#   Downloading https://pypi.doubanio.com/packages/3c/77/e2362b676dc5008d81be423070dd9577fa03be5da2ba1105811900fda546/packaging-21.0-py3-none-any.whl (40 kB)
# Collecting tornado>=5.1
#   Downloading https://pypi.doubanio.com/packages/91/a8/9c5902233fa3c2e6a889cbd164333ddda5009669f494e3fadbeee2c03af5/tornado-6.1-cp37-cp37m-manylinux2010_x86_64.whl (428 kB)
# Collecting typing_extensions>=3.7.4
#   Downloading https://pypi.doubanio.com/packages/2e/35/6c4fff5ab443b57116cb1aad46421fb719bed2825664e8fe77d66d99bcbc/typing_extensions-3.10.0.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in /miniconda3/lib/python3.7/site-packages (from jinja2->-r /requirements.txt (line 7)) (1.1.1)
# Collecting pyparsing>=2.0.2
#   Downloading https://pypi.doubanio.com/packages/8a/bb/488841f56197b13700afd5658fc279a2025a39e22449b7cf29864669b15d/pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
# Requirement already satisfied: six>=1.5 in /miniconda3/lib/python3.7/site-packages (from python-dateutil>=2.1->bokeh->-r /requirements.txt (line 4)) (1.15.0)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /miniconda3/lib/python3.7/site-packages (from boto3->-r /requirements.txt (line 5)) (0.3.6)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /miniconda3/lib/python3.7/site-packages (from boto3->-r /requirements.txt (line 5)) (0.10.0)
# Requirement already satisfied: botocore<1.21.0,>=1.20.36 in /miniconda3/lib/python3.7/site-packages (from boto3->-r /requirements.txt (line 5)) (1.20.36)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /miniconda3/lib/python3.7/site-packages (from botocore<1.21.0,>=1.20.36->boto3->-r /requirements.txt (line 5)) (1.26.4)
# Requirement already satisfied: requests!=2.18.0,>=2.14.2 in /miniconda3/lib/python3.7/site-packages (from docker->-r /requirements.txt (line 6)) (2.25.1)
# Collecting websocket-client>=0.32.0
#   Downloading https://pypi.doubanio.com/packages/36/48/092d9431a83ae39b72de76109a56f0353d68e229c9c2b27151fc5c61ee12/websocket_client-1.2.0-py2.py3-none-any.whl (52 kB)
# Requirement already satisfied: chardet<5,>=3.0.2 in /miniconda3/lib/python3.7/site-packages (from requests!=2.18.0,>=2.14.2->docker->-r /requirements.txt (line 6)) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /miniconda3/lib/python3.7/site-packages (from requests!=2.18.0,>=2.14.2->docker->-r /requirements.txt (line 6)) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /miniconda3/lib/python3.7/site-packages (from requests!=2.18.0,>=2.14.2->docker->-r /requirements.txt (line 6)) (2.10)
# Collecting pyrsistent>=0.14.0
#   Downloading https://pypi.doubanio.com/packages/b6/31/6e33022d5056ac64972f2d1411ba04261668e5d4e90b23c115f2e81283bc/pyrsistent-0.18.0-cp37-cp37m-manylinux1_x86_64.whl (119 kB)
# Collecting importlib-metadata
#   Downloading https://pypi.doubanio.com/packages/07/76/c4674c460f5ff4b5f7a962214e46295e20504dfde9fcba78fd728dfe2ac9/importlib_metadata-4.6.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: setuptools in /miniconda3/lib/python3.7/site-packages (from jsonschema->-r /requirements.txt (line 8)) (52.0.0.post20210125)
# Collecting attrs>=17.4.0
#   Downloading https://pypi.doubanio.com/packages/20/a9/ba6f1cd1a1517ff022b35acd6a7e4246371dfab08b8e42b829b6d07913cc/attrs-21.2.0-py2.py3-none-any.whl (53 kB)
# Requirement already satisfied: scipy in /miniconda3/lib/python3.7/site-packages (from lightgbm->-r /requirements.txt (line 1)) (1.6.2)
# Requirement already satisfied: wheel in /miniconda3/lib/python3.7/site-packages (from lightgbm->-r /requirements.txt (line 1)) (0.36.2)
# Requirement already satisfied: scikit-learn!=0.22.0 in /miniconda3/lib/python3.7/site-packages (from lightgbm->-r /requirements.txt (line 1)) (0.20.0)
# Requirement already satisfied: pytz>=2017.2 in /miniconda3/lib/python3.7/site-packages (from pandas->-r /requirements.txt (line 10)) (2021.1)
# Collecting google-pasta
#   Downloading https://pypi.doubanio.com/packages/a3/de/c648ef6835192e6e2cc03f40b19eeda4382c49b5bafb43d88b931c4c74ac/google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Requirement already satisfied: protobuf>=3.1 in /miniconda3/lib/python3.7/site-packages (from sagemaker->-r /requirements.txt (line 11)) (3.15.6)
# Collecting protobuf3-to-dict>=0.1.5
#   Downloading https://pypi.doubanio.com/packages/6b/55/522bb43539fed463275ee803d79851faaebe86d17e7e3dbc89870d0322b9/protobuf3-to-dict-0.1.5.tar.gz (3.5 kB)
# Collecting smdebug_rulesconfig==1.0.1
#   Downloading https://pypi.doubanio.com/packages/26/a1/45a13a05198bbe9527bab2c5e5daa8bd02678aa825eec14783e767bfa7d1/smdebug_rulesconfig-1.0.1-py2.py3-none-any.whl (20 kB)
# Collecting pathos
#   Downloading https://pypi.doubanio.com/packages/23/6b/7ffe02bdb5f5cf4b2290cc906b415dde7c886dbb11928dda40d39e6654dd/pathos-0.2.8-py2.py3-none-any.whl (81 kB)
# Collecting zipp>=0.5
#   Downloading https://pypi.doubanio.com/packages/92/d9/89f433969fb8dc5b9cbdd4b4deb587720ec1aeb59a020cf15002b9593eef/zipp-3.5.0-py3-none-any.whl (5.7 kB)
# Requirement already satisfied: tqdm>4.25.0 in /miniconda3/lib/python3.7/site-packages (from shap->-r /requirements.txt (line 3)) (4.59.0)
# Collecting slicer==0.0.7
#   Downloading https://pypi.doubanio.com/packages/78/c2/b3f55dfdb8af9812fdb9baf70cacf3b9e82e505b2bd4324d588888b81202/slicer-0.0.7-py3-none-any.whl (14 kB)
# Collecting numba
#   Downloading https://pypi.doubanio.com/packages/bb/73/d9c127eddbe3c105a33379d425b88f9dca249a6eddf39ce886494d49c3f9/numba-0.53.1-cp37-cp37m-manylinux2014_x86_64.whl (3.4 MB)
# Collecting cloudpickle
#   Downloading https://pypi.doubanio.com/packages/e7/e3/898487e5dbeb612054cf2e0c188463acb358167fef749c53c8bb8918cea1/cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting llvmlite<0.37,>=0.36.0rc1
#   Downloading https://pypi.doubanio.com/packages/54/25/2b4015e2b0c3be2efa6870cf2cf2bd969dd0e5f937476fc13c102209df32/llvmlite-0.36.0-cp37-cp37m-manylinux2010_x86_64.whl (25.3 MB)
# Collecting dill>=0.3.4
#   Downloading https://pypi.doubanio.com/packages/b6/c3/973676ceb86b60835bb3978c6db67a5dc06be6cfdbd14ef0f5a13e3fc9fd/dill-0.3.4-py2.py3-none-any.whl (86 kB)
# Collecting pox>=0.3.0
#   Downloading https://pypi.doubanio.com/packages/25/6e/7bc83d285dd0438f6ba106dba4fa85e569b09bae14f3c8d9df7acdc92629/pox-0.3.0-py2.py3-none-any.whl (30 kB)
# Collecting multiprocess>=0.70.12
#   Downloading https://pypi.doubanio.com/packages/aa/d8/d7bbcef5c03890f5fe983d8419b0c5236af3657c5aa9bddf1991a6ed813a/multiprocess-0.70.12.2-py37-none-any.whl (112 kB)
# Collecting ppft>=1.6.6.4
#   Downloading https://pypi.doubanio.com/packages/e1/95/17253538621d21308a6e7ca67cd8f87c64e81f95477e57ee78766cf79aaa/ppft-1.6.6.4-py3-none-any.whl (65 kB)
# Building wheels for collected packages: bokeh, sagemaker, protobuf3-to-dict, shap
#   Building wheel for bokeh (setup.py): started
#   Building wheel for bokeh (setup.py): finished with status 'done'
#   Created wheel for bokeh: filename=bokeh-2.3.3-py3-none-any.whl size=11342778 sha256=ddc4ce18f8359bfd743d571f4af9e7696807e8334502d01000ef601b7662945d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-wpq67imk/wheels/8e/8d/46/d079424cbb9689b12ee73cc75d7b0dc5a83ebd4f531f4b0a3c
#   Building wheel for sagemaker (setup.py): started
#   Building wheel for sagemaker (setup.py): finished with status 'done'
#   Created wheel for sagemaker: filename=sagemaker-2.53.0-py2.py3-none-any.whl size=614386 sha256=fb1a0adbc26b001513fa5d0db1c933cc995a6029cf226d71902fe0030ae47bab
#   Stored in directory: /tmp/pip-ephem-wheel-cache-wpq67imk/wheels/3f/a9/84/5ae7e479aa3a41a357ff6a2d704e528855cc4e2b12708e976d
#   Building wheel for protobuf3-to-dict (setup.py): started
#   Building wheel for protobuf3-to-dict (setup.py): finished with status 'done'
#   Created wheel for protobuf3-to-dict: filename=protobuf3_to_dict-0.1.5-py3-none-any.whl size=4030 sha256=ac3b6d0dad2d8d421914f028b795ba406dac011ddf4b00a20a6284e4cf6f0248
#   Stored in directory: /tmp/pip-ephem-wheel-cache-wpq67imk/wheels/df/3d/b7/404d817ce7fceb8ad7dae3d60f7b2dea1035adf78ffae704ca
#   Building wheel for shap (setup.py): started
#   Building wheel for shap (setup.py): finished with status 'done'
#   Created wheel for shap: filename=shap-0.39.0-cp37-cp37m-linux_x86_64.whl size=486689 sha256=bcf6a78ec0a58f045e1a125217a97b1a7bd432abfdbe51fcb14be208292e89eb
#   Stored in directory: /tmp/pip-ephem-wheel-cache-wpq67imk/wheels/82/ad/a1/a240bd8026a0a0e51a7ae01fd5a1fb312841b6f2ba4dc10a9b
# Successfully built bokeh sagemaker protobuf3-to-dict shap
# Installing collected packages: dill, zipp, typing-extensions, pyparsing, ppft, pox, multiprocess, llvmlite, websocket-client, tornado, smdebug-rulesconfig, slicer, PyYAML, pyrsistent, protobuf3-to-dict, pillow, pathos, packaging, numba, importlib-metadata, google-pasta, cloudpickle, attrs, shap, sagemaker, lightgbm, jsonschema, joblib, docker, bokeh
# Successfully installed PyYAML-5.4.1 attrs-21.2.0 bokeh-2.3.3 cloudpickle-1.6.0 dill-0.3.4 docker-5.0.0 google-pasta-0.2.0 importlib-metadata-4.6.3 joblib-1.0.1 jsonschema-3.2.0 lightgbm-3.2.1 llvmlite-0.36.0 multiprocess-0.70.12.2 numba-0.53.1 packaging-21.0 pathos-0.2.8 pillow-8.3.1 pox-0.3.0 ppft-1.6.6.4 protobuf3-to-dict-0.1.5 pyparsing-2.4.7 pyrsistent-0.18.0 sagemaker-2.53.0 shap-0.39.0 slicer-0.0.7 smdebug-rulesconfig-1.0.1 tornado-6.1 typing-extensions-3.10.0.0 websocket-client-1.2.0 zipp-3.5.0
# Removing intermediate container fabcd9b9c016
#  ---> 4778ac5635fe
# Successfully built 4778ac5635fe
# Successfully tagged training-lightgbm:latest
# The push refers to repository [542319707026.dkr.ecr.cn-northwest-1.amazonaws.com.cn/training-lightgbm]
#
# cdc3261f: Preparing
# 87eb1dbf: Preparing
# 1a26d0f9: Preparing
# df204d60: Preparing
# a112a1f9: Preparing
# 205eb8a5: Preparing
# 9e8799af: Preparing
# 08320039: Preparing
# 78afdd7d: Preparing
# 68fe446b: Preparing
# d2b930fc: Preparing
# ec0db89a: Preparing
# 49baa658: Preparing
# 08320039: Pushed   1.736GB/1.678GBPushing  69.06MB/167.9MBPushing  94.13MB/167.9MBPushing  707.9MB/1.678GBlatest: digest: sha256:ff12034bea794bddf60a4744eed8c5b1d5b76400d1d0da83cf5c02fd3efe4f1b size: 3255
# CPU times: user 1.32 s, sys: 390 ms, total: 1.71 s
# Wall time: 1min 46s

# %% [markdown]
# ### 模型训练

# %%
hyperparameters = {
    "tree_n_estimators": 20000,
    "tree_max_depth": 2,
    "tree_num_leaves": 31,
    "tree_min_child_samples": 1,
    "tree_boosting_type": "dart",
    "min_child_weight":0.0001
}

_metric_definitions = []
_metric_definitions.append({'Name':'validation_l2','Regex':' l2: ([-+]?[0-9]*[.]?[0-9]+([eE][-+]?[0-9]+)?)'})

_estimator = SKLearn(
    image_uri='542319707026.dkr.ecr.cn-northwest-1.amazonaws.com.cn/training-lightgbm',
    entry_point='entry_point.py',
    source_dir='training_code',
    hyperparameters=hyperparameters,
    metric_definitions=_metric_definitions,
    role=sagemaker.get_execution_role(),
    instance_count=1,
    instance_type='ml.c5.xlarge',
    output_path='s3://sagemaker-cn-northwest-1-542319707026/baozun/lightgbm/output',
    base_job_name='lightgbm-model-training',
    disable_profiler=True
)

# %%
data_channels = {
    'x_train': 's3://sagemaker-cn-northwest-1-542319707026/baozun/datasets/X_train.csv',
    'y_train': 's3://sagemaker-cn-northwest-1-542319707026/baozun/datasets/y_train.csv',
    'x_test': 's3://sagemaker-cn-northwest-1-542319707026/baozun/datasets/X_test.csv',
    'y_test': 's3://sagemaker-cn-northwest-1-542319707026/baozun/datasets/y_test.csv'
                }

_estimator.fit(data_channels)
# Out:
# 2021-08-13 08:34:02 Starting - Starting the training job...
# 2021-08-13 08:34:04 Starting - Launching requested ML instances...
# 2021-08-13 08:34:52 Starting - Preparing the instances for training......
# 2021-08-13 08:35:53 Downloading - Downloading input data...
# 2021-08-13 08:36:08 Training - Downloading the training image........2021-08-13 08:37:37,741 sagemaker-containers INFO     Imported framework sagemaker_sklearn_container.training
# 2021-08-13 08:37:37,743 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-08-13 08:37:37,751 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 2021-08-13 08:37:38,055 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-08-13 08:37:38,670 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-08-13 08:37:38,681 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-08-13 08:37:38,690 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "x_train": "/opt/ml/input/data/x_train",
#         "y_test": "/opt/ml/input/data/y_test",
#         "y_train": "/opt/ml/input/data/y_train",
#         "x_test": "/opt/ml/input/data/x_test"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_sklearn_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "tree_min_child_samples": 1,
#         "tree_num_leaves": 31,
#         "tree_n_estimators": 20000,
#         "tree_boosting_type": "dart",
#         "min_child_weight": 0.0001,
#         "tree_max_depth": 2
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "x_train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "y_test": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "y_train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "x_test": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "lightgbm-model-training-2021-08-13-08-34-01-741",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-cn-northwest-1-542319707026/lightgbm-model-training-2021-08-13-08-34-01-741/source/sourcedir.tar.gz",
#     "module_name": "entry_point",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "entry_point.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"min_child_weight":0.0001,"tree_boosting_type":"dart","tree_max_depth":2,"tree_min_child_samples":1,"tree_n_estimators":20000,"tree_num_leaves":31}
# SM_USER_ENTRY_POINT=entry_point.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"x_test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"x_train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"y_test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"y_train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["x_test","x_train","y_test","y_train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=entry_point
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_sklearn_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-cn-northwest-1-542319707026/lightgbm-model-training-2021-08-13-08-34-01-741/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"x_test":"/opt/ml/input/data/x_test","x_train":"/opt/ml/input/data/x_train","y_test":"/opt/ml/input/data/y_test","y_train":"/opt/ml/input/data/y_train"},"current_host":"algo-1","framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{"min_child_weight":0.0001,"tree_boosting_type":"dart","tree_max_depth":2,"tree_min_child_samples":1,"tree_n_estimators":20000,"tree_num_leaves":31},"input_config_dir":"/opt/ml/input/config","input_data_config":{"x_test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"x_train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"y_test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"y_train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"lightgbm-model-training-2021-08-13-08-34-01-741","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-cn-northwest-1-542319707026/lightgbm-model-training-2021-08-13-08-34-01-741/source/sourcedir.tar.gz","module_name":"entry_point","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"entry_point.py"}
# SM_USER_ARGS=["--min_child_weight","0.0001","--tree_boosting_type","dart","--tree_max_depth","2","--tree_min_child_samples","1","--tree_n_estimators","20000","--tree_num_leaves","31"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_X_TRAIN=/opt/ml/input/data/x_train
# SM_CHANNEL_Y_TEST=/opt/ml/input/data/y_test
# SM_CHANNEL_Y_TRAIN=/opt/ml/input/data/y_train
# SM_CHANNEL_X_TEST=/opt/ml/input/data/x_test
# SM_HP_TREE_MIN_CHILD_SAMPLES=1
# SM_HP_TREE_NUM_LEAVES=31
# SM_HP_TREE_N_ESTIMATORS=20000
# SM_HP_TREE_BOOSTING_TYPE=dart
# SM_HP_MIN_CHILD_WEIGHT=0.0001
# SM_HP_TREE_MAX_DEPTH=2
# PYTHONPATH=/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python37.zip:/miniconda3/lib/python3.7:/miniconda3/lib/python3.7/lib-dynload:/miniconda3/lib/python3.7/site-packages
#
# Invoking script with the following command:
#
# /miniconda3/bin/python entry_point.py --min_child_weight 0.0001 --tree_boosting_type dart --tree_max_depth 2 --tree_min_child_samples 1 --tree_n_estimators 20000 --tree_num_leaves 31
#
#
# /miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/externals/cloudpickle/cloudpickle.py:47: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp
# /miniconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:34: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from ._gradient_boosting import predict_stages
# /miniconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:34: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from ._gradient_boosting import predict_stages
# [1]#011valid_0's l1: 0.07045#011valid_0's l2: 0.0187944
# /miniconda3/lib/python3.7/site-packages/lightgbm/callback.py:183: UserWarning: Early stopping is not available in dart mode
#   _log_warning('Early stopping is not available in dart mode')
# [2]#011valid_0's l1: 0.0641928#011valid_0's l2: 0.0158095
# [3]#011valid_0's l1: 0.0588386#011valid_0's l2: 0.0132387
# [4]#011valid_0's l1: 0.0534835#011valid_0's l2: 0.0112244
# [5]#011valid_0's l1: 0.0494971#011valid_0's l2: 0.00952894
# [6]#011valid_0's l1: 0.0447331#011valid_0's l2: 0.00804621
# [7]#011valid_0's l1: 0.0410556#011valid_0's l2: 0.00689497
# [8]#011valid_0's l1: 0.0430844#011valid_0's l2: 0.00750067
# [9]#011valid_0's l1: 0.0392462#011valid_0's l2: 0.00647231
# [10]#011valid_0's l1: 0.0358552#011valid_0's l2: 0.00558315
# [11]#011valid_0's l1: 0.0328214#011valid_0's l2: 0.00465591
# [12]#011valid_0's l1: 0.0340703#011valid_0's l2: 0.0049933
# [13]#011valid_0's l1: 0.0314243#011valid_0's l2: 0.00416945
# [14]#011valid_0's l1: 0.0290887#011valid_0's l2: 0.00354431
# [15]#011valid_0's l1: 0.0265948#011valid_0's l2: 0.00304326
# [16]#011valid_0's l1: 0.0243599#011valid_0's l2: 0.0026586
# [17]#011valid_0's l1: 0.0223693#011valid_0's l2: 0.00233883
# [18]#011valid_0's l1: 0.0205638#011valid_0's l2: 0.00199513
# [19]#011valid_0's l1: 0.0188431#011valid_0's l2: 0.00174902
# [20]#011valid_0's l1: 0.0174906#011valid_0's l2: 0.00148341
# [21]#011valid_0's l1: 0.0182519#011valid_0's l2: 0.00160951
# [22]#011valid_0's l1: 0.0169823#011valid_0's l2: 0.00138423
# [23]#011valid_0's l1: 0.0156756#011valid_0's l2: 0.00123626
# [24]#011valid_0's l1: 0.0145659#011valid_0's l2: 0.00111107
# [25]#011valid_0's l1: 0.0133801#011valid_0's l2: 0.000966116
# [26]#011valid_0's l1: 0.0124135#011valid_0's l2: 0.000873365
# [27]#011valid_0's l1: 0.0114135#011valid_0's l2: 0.000772139
# [28]#011valid_0's l1: 0.0120643#011valid_0's l2: 0.000838455
# [29]#011valid_0's l1: 0.0110937#011valid_0's l2: 0.000730081
# [30]#011valid_0's l1: 0.0103593#011valid_0's l2: 0.000652939
# [31]#011valid_0's l1: 0.0108519#011valid_0's l2: 0.000697093
# [32]#011valid_0's l1: 0.0101669#011valid_0's l2: 0.000635521
# [33]#011valid_0's l1: 0.00956095#011valid_0's l2: 0.000566944
# [34]#011valid_0's l1: 0.00898913#011valid_0's l2: 0.000524452
# [35]#011valid_0's l1: 0.00960622#011valid_0's l2: 0.00057361
# [36]#011valid_0's l1: 0.0109808#011valid_0's l2: 0.00069176
# [37]#011valid_0's l1: 0.0102584#011valid_0's l2: 0.00063297
# [38]#011valid_0's l1: 0.00963178#011valid_0's l2: 0.000564601
# [39]#011valid_0's l1: 0.00904424#011valid_0's l2: 0.000523742
# [40]#011valid_0's l1: 0.0093621#011valid_0's l2: 0.000549219
# [41]#011valid_0's l1: 0.0101947#011valid_0's l2: 0.000621971
# [42]#011valid_0's l1: 0.00956704#011valid_0's l2: 0.000570301
# [43]#011valid_0's l1: 0.0101612#011valid_0's l2: 0.000617824
# [44]#011valid_0's l1: 0.00950693#011valid_0's l2: 0.000567312
# [45]#011valid_0's l1: 0.00889278#011valid_0's l2: 0.000514254
# [46]#011valid_0's l1: 0.00956281#011valid_0's l2: 0.000722485
# [47]#011valid_0's l1: 0.0090337#011valid_0's l2: 0.000655743
# [48]#011valid_0's l1: 0.0093179#011valid_0's l2: 0.000677924
# [49]#011valid_0's l1: 0.00997998#011valid_0's l2: 0.000752764
# [50]#011valid_0's l1: 0.0106891#011valid_0's l2: 0.000832871
# [51]#011valid_0's l1: 0.0100799#011valid_0's l2: 0.000747584
# [52]#011valid_0's l1: 0.00933071#011valid_0's l2: 0.000678727
# [53]#011valid_0's l1: 0.0100226#011valid_0's l2: 0.000768741
# [54]#011valid_0's l1: 0.00952564#011valid_0's l2: 0.000697369
# [55]#011valid_0's l1: 0.009018#011valid_0's l2: 0.000622562
# [56]#011valid_0's l1: 0.00990593#011valid_0's l2: 0.000699719
# [57]#011valid_0's l1: 0.00922034#011valid_0's l2: 0.000640062
# [58]#011valid_0's l1: 0.01111#011valid_0's l2: 0.0008557
# [59]#011valid_0's l1: 0.0115311#011valid_0's l2: 0.000988607
# [60]#011valid_0's l1: 0.0107686#011valid_0's l2: 0.000877282
# [61]#011valid_0's l1: 0.0151721#011valid_0's l2: 0.00111001
# [62]#011valid_0's l1: 0.0138518#011valid_0's l2: 0.000980583
# [63]#011valid_0's l1: 0.012698#011valid_0's l2: 0.000875805
# [64]#011valid_0's l1: 0.0125684#011valid_0's l2: 0.000960766
# [65]#011valid_0's l1: 0.0126562#011valid_0's l2: 0.00100664
# [66]#011valid_0's l1: 0.0116171#011valid_0's l2: 0.000899451
# [67]#011valid_0's l1: 0.0105953#011valid_0's l2: 0.000789062
# [68]#011valid_0's l1: 0.00971677#011valid_0's l2: 0.000714708
# [69]#011valid_0's l1: 0.00984769#011valid_0's l2: 0.000763655
# [70]#011valid_0's l1: 0.010098#011valid_0's l2: 0.000789722
# [71]#011valid_0's l1: 0.0107375#011valid_0's l2: 0.000872317
# [72]#011valid_0's l1: 0.010082#011valid_0's l2: 0.000791058
# [73]#011valid_0's l1: 0.00952155#011valid_0's l2: 0.000700408
# [74]#011valid_0's l1: 0.00981568#011valid_0's l2: 0.000735571
# [75]#011valid_0's l1: 0.00930656#011valid_0's l2: 0.00065051
# [76]#011valid_0's l1: 0.00934311#011valid_0's l2: 0.000658244
# [77]#011valid_0's l1: 0.00967998#011valid_0's l2: 0.00069876
# [78]#011valid_0's l1: 0.0102755#011valid_0's l2: 0.000784534
# [79]#011valid_0's l1: 0.00972084#011valid_0's l2: 0.000710636
# [80]#011valid_0's l1: 0.00902493#011valid_0's l2: 0.000648078
# [81]#011valid_0's l1: 0.00950253#011valid_0's l2: 0.000703968
# [82]#011valid_0's l1: 0.00896713#011valid_0's l2: 0.000627336
# [83]#011valid_0's l1: 0.00949641#011valid_0's l2: 0.000690757
# [84]#011valid_0's l1: 0.00989275#011valid_0's l2: 0.000729959
# [85]#011valid_0's l1: 0.0103738#011valid_0's l2: 0.000792837
# [86]#011valid_0's l1: 0.00963632#011valid_0's l2: 0.000712874
# [87]#011valid_0's l1: 0.0089916#011valid_0's l2: 0.000636313
# [88]#011valid_0's l1: 0.00953914#011valid_0's l2: 0.000693839
# [89]#011valid_0's l1: 0.0100268#011valid_0's l2: 0.000751096
# [90]#011valid_0's l1: 0.0104355#011valid_0's l2: 0.000799555
# [91]#011valid_0's l1: 0.0112564#011valid_0's l2: 0.000947896
# [92]#011valid_0's l1: 0.0106764#011valid_0's l2: 0.000849475
# [93]#011valid_0's l1: 0.0100833#011valid_0's l2: 0.000749069
# [94]#011valid_0's l1: 0.0104069#011valid_0's l2: 0.000791709
# [95]#011valid_0's l1: 0.010826#011valid_0's l2: 0.000846067
# [96]#011valid_0's l1: 0.0111616#011valid_0's l2: 0.000893578
# [97]#011valid_0's l1: 0.010465#011valid_0's l2: 0.000800863
# [98]#011valid_0's l1: 0.0109157#011valid_0's l2: 0.000865732
# [99]#011valid_0's l1: 0.0101277#011valid_0's l2: 0.000784298
# [100]#011valid_0's l1: 0.00951277#011valid_0's l2: 0.000686783
# [101]#011valid_0's l1: 0.0103361#011valid_0's l2: 0.000804113
# [102]#011valid_0's l1: 0.0106521#011valid_0's l2: 0.000841539
# [103]#011valid_0's l1: 0.0110536#011valid_0's l2: 0.000896162
# [104]#011valid_0's l1: 0.0103899#011valid_0's l2: 0.000804787
# [105]#011valid_0's l1: 0.0111154#011valid_0's l2: 0.000924918
# [106]#011valid_0's l1: 0.0115811#011valid_0's l2: 0.000988589
# [107]#011valid_0's l1: 0.0120777#011valid_0's l2: 0.00106072
# [108]#011valid_0's l1: 0.0113715#011valid_0's l2: 0.000943778
# [109]#011valid_0's l1: 0.0117249#011valid_0's l2: 0.000991668
# [110]#011valid_0's l1: 0.0121692#011valid_0's l2: 0.00105221
# [111]#011valid_0's l1: 0.0113476#011valid_0's l2: 0.0009343
# [112]#011valid_0's l1: 0.0104124#011valid_0's l2: 0.00083766
# [113]#011valid_0's l1: 0.009572#011valid_0's l2: 0.000759274
# [114]#011valid_0's l1: 0.00905664#011valid_0's l2: 0.000669772
# [115]#011valid_0's l1: 0.00850088#011valid_0's l2: 0.000598424
# [116]#011valid_0's l1: 0.008101#011valid_0's l2: 0.000535915
# [117]#011valid_0's l1: 0.00848401#011valid_0's l2: 0.000573704
# [118]#011valid_0's l1: 0.0079499#011valid_0's l2: 0.000528767
# [119]#011valid_0's l1: 0.00829518#011valid_0's l2: 0.000564162
# [120]#011valid_0's l1: 0.00868251#011valid_0's l2: 0.000607068
# [121]#011valid_0's l1: 0.0090652#011valid_0's l2: 0.000645276
# [122]#011valid_0's l1: 0.00958228#011valid_0's l2: 0.000693631
# [123]#011valid_0's l1: 0.00901644#011valid_0's l2: 0.000633019
# [124]#011valid_0's l1: 0.00848589#011valid_0's l2: 0.000573489
# [125]#011valid_0's l1: 0.00896743#011valid_0's l2: 0.000626313
# [126]#011valid_0's l1: 0.00926268#011valid_0's l2: 0.000659424
# [127]#011valid_0's l1: 0.00877606#011valid_0's l2: 0.000589294
# [128]#011valid_0's l1: 0.00917567#011valid_0's l2: 0.000634307
# [129]#011valid_0's l1: 0.00860844#011valid_0's l2: 0.000581306
# [130]#011valid_0's l1: 0.00798469#011valid_0's l2: 0.000534266
# [131]#011valid_0's l1: 0.00823689#011valid_0's l2: 0.000558868
# [132]#011valid_0's l1: 0.00780837#011valid_0's l2: 0.000497808
# [133]#011valid_0's l1: 0.00733502#011valid_0's l2: 0.000460564
# [134]#011valid_0's l1: 0.00778086#011valid_0's l2: 0.000517625
# [135]#011valid_0's l1: 0.00736488#011valid_0's l2: 0.000473739
# [136]#011valid_0's l1: 0.00815934#011valid_0's l2: 0.000559499
# [137]#011valid_0's l1: 0.0084491#011valid_0's l2: 0.000603196
# [138]#011valid_0's l1: 0.0080053#011valid_0's l2: 0.000550415
# [139]#011valid_0's l1: 0.00757609#011valid_0's l2: 0.000497434
# [140]#011valid_0's l1: 0.00797049#011valid_0's l2: 0.000536845
# [141]#011valid_0's l1: 0.00829836#011valid_0's l2: 0.000569375
# [142]#011valid_0's l1: 0.00864015#011valid_0's l2: 0.000605271
# [143]#011valid_0's l1: 0.00808402#011valid_0's l2: 0.000550332
# [144]#011valid_0's l1: 0.00839156#011valid_0's l2: 0.000578921
# [145]#011valid_0's l1: 0.00797962#011valid_0's l2: 0.000519834
# [146]#011valid_0's l1: 0.00837725#011valid_0's l2: 0.000563252
# [147]#011valid_0's l1: 0.00867642#011valid_0's l2: 0.000594743
# [148]#011valid_0's l1: 0.00911935#011valid_0's l2: 0.000640989
# [149]#011valid_0's l1: 0.00856941#011valid_0's l2: 0.000584294
# [150]#011valid_0's l1: 0.00789463#011valid_0's l2: 0.000535468
# [151]#011valid_0's l1: 0.00841326#011valid_0's l2: 0.000595192
# [152]#011valid_0's l1: 0.00890194#011valid_0's l2: 0.000654502
# [153]#011valid_0's l1: 0.00840098#011valid_0's l2: 0.000595284
# [154]#011valid_0's l1: 0.00866172#011valid_0's l2: 0.00062459
# [155]#011valid_0's l1: 0.00824464#011valid_0's l2: 0.000567327
# [156]#011valid_0's l1: 0.00857923#011valid_0's l2: 0.000600697
# [157]#011valid_0's l1: 0.00877708#011valid_0's l2: 0.000620824
# [158]#011valid_0's l1: 0.00908216#011valid_0's l2: 0.000655761
# [159]#011valid_0's l1: 0.00941311#011valid_0's l2: 0.000689628
# [160]#011valid_0's l1: 0.00970955#011valid_0's l2: 0.000724933
# [161]#011valid_0's l1: 0.00919215#011valid_0's l2: 0.000655997
# [162]#011valid_0's l1: 0.00952432#011valid_0's l2: 0.00069564
# [163]#011valid_0's l1: 0.00900531#011valid_0's l2: 0.000618527
# [164]#011valid_0's l1: 0.00838402#011valid_0's l2: 0.000566284
# [165]#011valid_0's l1: 0.00799901#011valid_0's l2: 0.000508951
# [166]#011valid_0's l1: 0.00741791#011valid_0's l2: 0.000470922
# [167]#011valid_0's l1: 0.00707368#011valid_0's l2: 0.000442629
# [168]#011valid_0's l1: 0.00663443#011valid_0's l2: 0.000413994
# [169]#011valid_0's l1: 0.0064053#011valid_0's l2: 0.000377615
# [170]#011valid_0's l1: 0.00670429#011valid_0's l2: 0.000413103
# [171]#011valid_0's l1: 0.00641026#011valid_0's l2: 0.00038976
# [172]#011valid_0's l1: 0.00668972#011valid_0's l2: 0.000427004
# [173]#011valid_0's l1: 0.00641027#011valid_0's l2: 0.00039236
# [174]#011valid_0's l1: 0.00611405#011valid_0's l2: 0.000364701
# [175]#011valid_0's l1: 0.00577267#011valid_0's l2: 0.000346784
# [176]#011valid_0's l1: 0.00595719#011valid_0's l2: 0.000363724
# [177]#011valid_0's l1: 0.00620778#011valid_0's l2: 0.000387516
# [178]#011valid_0's l1: 0.00649811#011valid_0's l2: 0.000414843
# [179]#011valid_0's l1: 0.00618536#011valid_0's l2: 0.000383551
# [180]#011valid_0's l1: 0.00638274#011valid_0's l2: 0.000402648
# [181]#011valid_0's l1: 0.00615057#011valid_0's l2: 0.000367317
# [182]#011valid_0's l1: 0.00584325#011valid_0's l2: 0.000347559
# [183]#011valid_0's l1: 0.00554387#011valid_0's l2: 0.000330285
# [184]#011valid_0's l1: 0.00542053#011valid_0's l2: 0.000316722
# [185]#011valid_0's l1: 0.00563589#011valid_0's l2: 0.000334059
# [186]#011valid_0's l1: 0.00544309#011valid_0's l2: 0.000319308
# [187]#011valid_0's l1: 0.00530592#011valid_0's l2: 0.000298472
# [188]#011valid_0's l1: 0.00522462#011valid_0's l2: 0.000288591
# [189]#011valid_0's l1: 0.00544525#011valid_0's l2: 0.000309151
# [190]#011valid_0's l1: 0.00566929#011valid_0's l2: 0.000329152
# [191]#011valid_0's l1: 0.00542699#011valid_0's l2: 0.000315578
# [192]#011valid_0's l1: 0.00531824#011valid_0's l2: 0.000299438
# [193]#011valid_0's l1: 0.00521811#011valid_0's l2: 0.000288961
# [194]#011valid_0's l1: 0.00535034#011valid_0's l2: 0.000304174
# [195]#011valid_0's l1: 0.00547513#011valid_0's l2: 0.000319139
# [196]#011valid_0's l1: 0.00529898#011valid_0's l2: 0.000306093
# [197]#011valid_0's l1: 0.0054305#011valid_0's l2: 0.000317015
# [198]#011valid_0's l1: 0.00559084#011valid_0's l2: 0.000333061
# [199]#011valid_0's l1: 0.00545416#011valid_0's l2: 0.000314075
# [200]#011valid_0's l1: 0.00560846#011valid_0's l2: 0.000332706
# 2021-08-13 08:37:39,970 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2021-08-13 08:37:50 Uploading - Uploading generated training model
# 2021-08-13 08:37:50 Completed - Training job completed
# Training seconds: 117
# Billable seconds: 117

# %% [markdown]
# ### 超参调优

# %%
### Hyperparameter Tuning

from time import gmtime, strftime
from sagemaker.tuner import IntegerParameter, CategoricalParameter, ContinuousParameter, HyperparameterTuner

_tuning_job_name = "bz-lightgbm-job-{}".format(strftime("%d-%H-%M-%S", gmtime()))

_hyperparameter_ranges = {
                        'tree_max_depth': IntegerParameter(2, 9),
                        'tree_num_leaves':IntegerParameter(25,35),
                        'tree_min_child_samples':IntegerParameter(20,25),
                        'min_child_weight':ContinuousParameter(0.001,0.01)
                        }


_tuner = HyperparameterTuner(estimator = _estimator,
                            objective_metric_name = 'validation_l2',
                            metric_definitions = [{'Name':'validation_l2','Regex':' l2: ([-+]?[0-9]*[.]?[0-9]+([eE][-+]?[0-9]+)?)'}],
                            hyperparameter_ranges = _hyperparameter_ranges,
                            objective_type='Minimize',
                            max_jobs=10,
                            strategy = 'Bayesian',
                            max_parallel_jobs=5)

_tuner.fit(data_channels, 
          job_name=_tuning_job_name,
          include_cls_metadata=False)
_tuner.wait()

tuner_metrics = sagemaker.HyperparameterTuningJobAnalytics(_tuning_job_name)
tuner_metrics.dataframe().sort_values(['FinalObjectiveValue'], ascending=False).head(5)
# Out:
# ................................................................................................................................................................................................................................................................!
# !
#     min_child_weight  tree_max_depth  tree_min_child_samples  tree_num_leaves  \
# 19          0.008552             4.0                    24.0             34.0
# 17          0.009498             8.0                    25.0             25.0
# 6           0.002503             2.0                    23.0             29.0
# 18          0.004052             4.0                    25.0             32.0
# 1           0.004967             5.0                    21.0             25.0
#
#                              TrainingJobName TrainingJobStatus  \
# 19  bz-lightgbm-job-13-09-11-40-001-2048998c         Completed
# 17  bz-lightgbm-job-13-09-11-40-003-0f4379bd         Completed
# 6   bz-lightgbm-job-13-09-11-40-014-21ca8141         Completed
# 18  bz-lightgbm-job-13-09-11-40-002-a54b4433         Completed
# 1   bz-lightgbm-job-13-09-11-40-019-85a8dd3c         Completed
#
#     FinalObjectiveValue         TrainingStartTime           TrainingEndTime  \
# 19             0.001010 2021-08-13 09:13:45+00:00 2021-08-13 09:16:27+00:00
# 17             0.000973 2021-08-13 09:13:55+00:00 2021-08-13 09:17:02+00:00
# 6              0.000948 2021-08-13 09:24:14+00:00 2021-08-13 09:26:33+00:00
# 18             0.000919 2021-08-13 09:14:00+00:00 2021-08-13 09:16:41+00:00
# 1              0.000854 2021-08-13 09:29:15+00:00 2021-08-13 09:32:20+00:00
#
#     TrainingElapsedTimeSeconds
# 19                       162.0
# 17                       187.0
# 6                        139.0
# 18                       161.0
# 1                        185.0

# %%
tuner_metrics = sagemaker.HyperparameterTuningJobAnalytics(_tuning_job_name)

# %%
tuner_metrics.dataframe().sort_values(['FinalObjectiveValue'], ascending=True).head(5)
# Out:
#     min_child_weight  tree_max_depth  tree_min_child_samples  tree_num_leaves  \
# 15          0.003259             3.0                    22.0             28.0
# 13          0.001000             3.0                    22.0             26.0
# 9           0.001218             2.0                    21.0             30.0
# 2           0.009292             2.0                    21.0             35.0
# 3           0.004865             2.0                    21.0             29.0
#
#                              TrainingJobName TrainingJobStatus  \
# 15  bz-lightgbm-job-13-09-11-40-005-6c6207ad         Completed
# 13  bz-lightgbm-job-13-09-11-40-007-4275574b         Completed
# 9   bz-lightgbm-job-13-09-11-40-011-e1ffe1c5         Completed
# 2   bz-lightgbm-job-13-09-11-40-018-79f394d8         Completed
# 3   bz-lightgbm-job-13-09-11-40-017-78387cda         Completed
#
#     FinalObjectiveValue         TrainingStartTime           TrainingEndTime  \
# 15             0.000727 2021-08-13 09:14:17+00:00 2021-08-13 09:16:49+00:00
# 13             0.000727 2021-08-13 09:19:31+00:00 2021-08-13 09:21:59+00:00
# 9              0.000733 2021-08-13 09:23:49+00:00 2021-08-13 09:26:31+00:00
# 2              0.000733 2021-08-13 09:29:24+00:00 2021-08-13 09:32:07+00:00
# 3              0.000733 2021-08-13 09:28:57+00:00 2021-08-13 09:31:21+00:00
#
#     TrainingElapsedTimeSeconds
# 15                       152.0
# 13                       148.0
# 9                        162.0
# 2                        163.0
# 3                        144.0

# %% [markdown]
# ### 模型在线服务

# %%
_estimartor = sagemaker.estimator.Estimator.attach('bz-lightgbm-job-13-09-11-40-005-6c6207ad')
# Out:
# 2021-08-13 09:16:49 Starting - Preparing the instances for training
# 2021-08-13 09:16:49 Downloading - Downloading input data
# 2021-08-13 09:16:49 Training - Training image download completed. Training in progress.
# 2021-08-13 09:16:49 Uploading - Uploading generated training model
# 2021-08-13 09:16:49 Completed - Training job completed

# %%
from sagemaker.sklearn import SKLearnModel

_endpoint_name = "endpoint-lightgbm-{}".format(strftime("%d-%H-%M-%S", gmtime()))

_model = SKLearnModel(
    model_data=_estimartor.model_data,
    role=sagemaker.get_execution_role(),
    entry_point='entry_point.py',
    source_dir='inference_code',
    framework_version = '0.20.0',
    py_version='py3'
)

# %%
_model.deploy(
    endpoint_name=_endpoint_name,
    instance_type='ml.c5.xlarge',
    initial_instance_count=1
)
# Out:
# --------------!

# %% [markdown]
# ### 模型在线服务调用

# %%
import boto3
import json

runtime_client = boto3.client('runtime.sagemaker', region_name='cn-northwest-1')

data = {'inputs':[[0.06349206349206349,533.0,1235.0,10.0,0.0,36.0,10.0,10.0,8.0,10.0,1290.0,8.0,8.0,8.0,468.63]]}

response = runtime_client.invoke_endpoint(EndpointName=_endpoint_name, 
                                   ContentType='application/json', 
                                   Body=json.dumps(data).encode('utf-8'))

result = response['Body'].read().decode('ascii')

print('Predicted label is {}'.format(result))
# Out:
# Predicted label is {"predictions":[0.01094387974143577]}

# %% [markdown]
# ### 模型批量转换

# %%
_estimartor = sagemaker.estimator.Estimator.attach('bz-lightgbm-job-13-09-11-40-005-6c6207ad')
# Out:
# 2021-08-13 09:16:49 Starting - Preparing the instances for training
# 2021-08-13 09:16:49 Downloading - Downloading input data
# 2021-08-13 09:16:49 Training - Training image download completed. Training in progress.
# 2021-08-13 09:16:49 Uploading - Uploading generated training model
# 2021-08-13 09:16:49 Completed - Training job completed

# %%
import sagemaker
from sagemaker.sklearn import SKLearnModel
model_data = "s3://sagemaker-us-west-2-517141035927/output/lightgbm-model-training-2021-10-26-12-17-52-220/output/model.tar.gz"
_model = SKLearnModel(
    model_data=model_data,
    role=sagemaker.get_execution_role(),
    entry_point='entry_point.py',
    source_dir='batch_code',
    framework_version = '0.20.0',
    py_version='py3'
)

# %%
# !pip install numpy pandas --upgrade

# %%
from sagemaker import get_execution_role
from time import strftime, gmtime
sagemaker_session = sagemaker.Session()

role = get_execution_role()
region = sagemaker_session.boto_session.region_name

prediction_data_path = 's3://sagemaker-us-west-2-517141035927/dataset/v_data.csv'
out_predict_data_path = 's3://sagemaker-us-west-2-517141035927/output/'

_instance_type = 'ml.c5.4xlarge'
_instance_count = 1

_max_concurrent_transforms = 1
_max_payload = 10

_job_name = 'lightgbm-batch-{}'.format(strftime("%Y-%m-%d-%H-%M-%S", gmtime()))
print(_job_name)

lightgbm_transformer = _model.transformer(
                            instance_count=_instance_count,
                            instance_type=_instance_type,
                            strategy = 'MultiRecord',
                            max_concurrent_transforms=_max_concurrent_transforms,
                            max_payload=_max_payload,
                            output_path=out_predict_data_path,
                            assemble_with='Line',
                            accept='text/csv')

lightgbm_transformer.transform(
    data=prediction_data_path,
    content_type='text/csv',
    split_type='Line',
#     input_filter="$[1:]",
#     join_source="Input",
#     output_filter="$[0 ,-1]",
    job_name=_job_name
)
lightgbm_transformer.wait()
# Out:
# lightgbm-batch-2021-10-27-11-59-34
# ............................Processing /opt/ml/code
# Building wheels for collected packages: entry-point
#   Building wheel for entry-point (setup.py): started
#   Building wheel for entry-point (setup.py): finished with status 'done'
#   Created wheel for entry-point: filename=entry_point-1.0.0-py2.py3-none-any.whl size=4835 sha256=fe76399590601d1ca9f552ff98f402a4c4737423d07e8e608b05bd5c60b916c6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ursdz_33/wheels/3e/0f/51/2f1df833dd0412c1bc2f5ee56baac195b5be563353d111dca6
# Successfully built entry-point
# Installing collected packages: entry-point
# Successfully installed entry-point-1.0.0
# Looking in indexes: https://pypi.douban.com/simple
# 2021/10/27 12:04:05 [crit] 25#25: *1 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:05 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/10/27 12:04:05 [crit] 25#25: *3 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:05 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/10/27 12:04:05 [crit] 25#25: *5 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:05 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/10/27 12:04:05 [crit] 25#25: *7 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:05 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/10/27 12:04:05 [crit] 25#25: *9 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:05 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/10/27 12:04:05 [crit] 25#25: *11 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:05 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/10/27 12:04:05 [crit] 25#25: *13 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:05 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/10/27 12:04:05 [crit] 25#25: *15 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:05 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/10/27 12:04:06 [crit] 25#25: *17 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:06 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# Collecting joblib
# 2021/10/27 12:04:06 [crit] 25#25: *19 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:06 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/10/27 12:04:06 [crit] 25#25: *21 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:06 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
#   Downloading https://pypi.doubanio.com/packages/3e/d5/0163eb0cfa0b673aa4fe1cd3ea9d8a81ea0f32e50807b0c295871e4aab2e/joblib-1.1.0-py2.py3-none-any.whl (306 kB)
# 2021/10/27 12:04:06 [crit] 25#25: *23 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:06 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/10/27 12:04:06 [crit] 25#25: *25 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:06 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/10/27 12:04:06 [crit] 25#25: *27 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:06 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/10/27 12:04:06 [crit] 25#25: *29 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:06 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/10/27 12:04:06 [crit] 25#25: *31 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:06 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/10/27 12:04:06 [crit] 25#25: *33 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:06 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/10/27 12:04:06 [crit] 25#25: *35 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:06 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# Collecting pathlib
# 2021/10/27 12:04:07 [crit] 25#25: *37 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:07 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
#   Downloading https://pypi.doubanio.com/packages/ac/aa/9b065a76b9af472437a0059f77e8f962fe350438b927cb80184c32f075eb/pathlib-1.0.1.tar.gz (49 kB)
# 2021/10/27 12:04:07 [crit] 25#25: *39 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:07 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/10/27 12:04:07 [crit] 25#25: *41 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:07 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/10/27 12:04:07 [crit] 25#25: *43 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:07 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/10/27 12:04:07 [crit] 25#25: *45 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:07 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/10/27 12:04:07 [crit] 25#25: *47 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:07 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/10/27 12:04:07 [crit] 25#25: *49 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:07 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# Collecting lightgbm
# 2021/10/27 12:04:07 [crit] 25#25: *51 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:07 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/10/27 12:04:07 [crit] 25#25: *53 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:07 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
#   Downloading https://pypi.doubanio.com/packages/58/f8/f1b63fe5e4c0706573b1f2645edf13e8b10f00ce18bb8abda5cddd723d46/lightgbm-3.3.0-py3-none-manylinux1_x86_64.whl (2.0 MB)
# 2021/10/27 12:04:07 [crit] 25#25: *55 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:07 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/10/27 12:04:08 [crit] 25#25: *57 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:08 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/10/27 12:04:08 [crit] 25#25: *59 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:08 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/10/27 12:04:08 [crit] 25#25: *61 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:08 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/10/27 12:04:08 [crit] 25#25: *63 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:08 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/10/27 12:04:08 [crit] 25#25: *65 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:08 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/10/27 12:04:08 [crit] 25#25: *67 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:08 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# Requirement already satisfied: scipy in /miniconda3/lib/python3.7/site-packages (from lightgbm) (1.6.2)
# Requirement already satisfied: numpy in /miniconda3/lib/python3.7/site-packages (from lightgbm) (1.20.1)
# Requirement already satisfied: scikit-learn!=0.22.0 in /miniconda3/lib/python3.7/site-packages (from lightgbm) (0.20.0)
# Requirement already satisfied: wheel in /miniconda3/lib/python3.7/site-packages (from lightgbm) (0.36.2)
# Building wheels for collected packages: pathlib
#   Building wheel for pathlib (setup.py): started
# 2021/10/27 12:04:08 [crit] 25#25: *69 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:08 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
#   Building wheel for pathlib (setup.py): finished with status 'done'
#   Created wheel for pathlib: filename=pathlib-1.0.1-py3-none-any.whl size=14347 sha256=36681c507a14a49d16f3ff1dc954facecd6a0c9c37b11b5ef0f3a81c56b1cf23
#   Stored in directory: /root/.cache/pip/wheels/44/b9/bb/fadee874f394af4e88557e3d4aaad5501c6da107333cd913c9
# 2021/10/27 12:04:08 [crit] 25#25: *71 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:08 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# Successfully built pathlib
# 2021/10/27 12:04:08 [crit] 25#25: *73 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:08 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# Installing collected packages: pathlib, lightgbm, joblib
# 2021/10/27 12:04:09 [crit] 25#25: *75 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:09 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/10/27 12:04:09 [crit] 25#25: *77 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:09 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/10/27 12:04:09 [crit] 25#25: *79 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:09 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# Successfully installed joblib-1.1.0 lightgbm-3.3.0 pathlib-1.0.1
# 2021/10/27 12:04:09 [crit] 25#25: *81 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:09 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/10/27 12:04:09 [crit] 25#25: *83 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:09 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/10/27 12:04:09 [crit] 25#25: *85 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:09 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/10/27 12:04:09 [crit] 25#25: *87 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:09 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# Looking in indexes: https://pypi.douban.com/simple
# Requirement already satisfied: joblib in /miniconda3/lib/python3.7/site-packages (1.1.0)
# Requirement already satisfied: pathlib in /miniconda3/lib/python3.7/site-packages (1.0.1)
# Requirement already satisfied: lightgbm in /miniconda3/lib/python3.7/site-packages (3.3.0)
# Requirement already satisfied: scikit-learn!=0.22.0 in /miniconda3/lib/python3.7/site-packages (from lightgbm) (0.20.0)
# Requirement already satisfied: numpy in /miniconda3/lib/python3.7/site-packages (from lightgbm) (1.20.1)
# Requirement already satisfied: scipy in /miniconda3/lib/python3.7/site-packages (from lightgbm) (1.6.2)
# Requirement already satisfied: wheel in /miniconda3/lib/python3.7/site-packages (from lightgbm) (0.36.2)
# 2021/10/27 12:04:09 [crit] 25#25: *89 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:09 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/10/27 12:04:09 [crit] 25#25: *91 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:09 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/10/27 12:04:09 [crit] 25#25: *93 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:09 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2021/10/27 12:04:10 [crit] 25#25: *95 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [27/Oct/2021:12:04:10 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# [2021-10-27 12:04:10 +0000] [74] [INFO] Starting gunicorn 20.0.4
# [2021-10-27 12:04:10 +0000] [74] [INFO] Listening at: unix:/tmp/gunicorn.sock (74)
# [2021-10-27 12:04:10 +0000] [74] [INFO] Using worker: gevent
# [2021-10-27 12:04:10 +0000] [77] [INFO] Booting worker with pid: 77
# [2021-10-27 12:04:10 +0000] [78] [INFO] Booting worker with pid: 78
# [2021-10-27 12:04:10 +0000] [94] [INFO] Booting worker with pid: 94
# [2021-10-27 12:04:10 +0000] [110] [INFO] Booting worker with pid: 110
# [2021-10-27 12:04:10 +0000] [111] [INFO] Booting worker with pid: 111
# [2021-10-27 12:04:10 +0000] [112] [INFO] Booting worker with pid: 112
# [2021-10-27 12:04:10 +0000] [113] [INFO] Booting worker with pid: 113
# [2021-10-27 12:04:10 +0000] [114] [INFO] Booting worker with pid: 114
# [2021-10-27 12:04:10 +0000] [160] [INFO] Booting worker with pid: 160
# [2021-10-27 12:04:10 +0000] [176] [INFO] Booting worker with pid: 176
# [2021-10-27 12:04:10 +0000] [177] [INFO] Booting worker with pid: 177
# [2021-10-27 12:04:10 +0000] [193] [INFO] Booting worker with pid: 193
# [2021-10-27 12:04:10 +0000] [194] [INFO] Booting worker with pid: 194
# [2021-10-27 12:04:10 +0000] [225] [INFO] Booting worker with pid: 225
# [2021-10-27 12:04:10 +0000] [226] [INFO] Booting worker with pid: 226
# [2021-10-27 12:04:10 +0000] [257] [INFO] Booting worker with pid: 257
# 2021-10-27 12:04:10,843 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# Looking in indexes: https://pypi.douban.com/simple
# Requirement already satisfied: joblib in /miniconda3/lib/python3.7/site-packages (1.1.0)
# Requirement already satisfied: pathlib in /miniconda3/lib/python3.7/site-packages (1.0.1)
# Requirement already satisfied: lightgbm in /miniconda3/lib/python3.7/site-packages (3.3.0)
# Requirement already satisfied: wheel in /miniconda3/lib/python3.7/site-packages (from lightgbm) (0.36.2)
# Requirement already satisfied: scikit-learn!=0.22.0 in /miniconda3/lib/python3.7/site-packages (from lightgbm) (0.20.0)
# Requirement already satisfied: numpy in /miniconda3/lib/python3.7/site-packages (from lightgbm) (1.20.1)
# Requirement already satisfied: scipy in /miniconda3/lib/python3.7/site-packages (from lightgbm) (1.6.2)
# /miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/externals/cloudpickle/cloudpickle.py:47: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp
# 169.254.255.130 - - [27/Oct/2021:12:04:11 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# 2021-10-27 12:04:11,930 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# Looking in indexes: https://pypi.douban.com/simple
# Requirement already satisfied: joblib in /miniconda3/lib/python3.7/site-packages (1.1.0)
# Requirement already satisfied: pathlib in /miniconda3/lib/python3.7/site-packages (1.0.1)
# Requirement already satisfied: lightgbm in /miniconda3/lib/python3.7/site-packages (3.3.0)
# Requirement already satisfied: numpy in /miniconda3/lib/python3.7/site-packages (from lightgbm) (1.20.1)
# Requirement already satisfied: scikit-learn!=0.22.0 in /miniconda3/lib/python3.7/site-packages (from lightgbm) (0.20.0)
# Requirement already satisfied: scipy in /miniconda3/lib/python3.7/site-packages (from lightgbm) (1.6.2)
# Requirement already satisfied: wheel in /miniconda3/lib/python3.7/site-packages (from lightgbm) (0.36.2)
# /miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/externals/cloudpickle/cloudpickle.py:47: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp
# 169.254.255.130 - - [27/Oct/2021:12:04:12 +0000] "GET /execution-parameters HTTP/1.1" 404 232 "-" "Go-http-client/1.1"
# 0,IN.MOHALLA.SHARECHAT,OTHERS,APPLICATIONS,SOCIAL,IN,ANDROID,VIVO,OTHERS,11,4.317488,3,5,3,1397,151,5,0.033112583,0,-20.72326584,-20.72326584,-20.72326584,-20.72326584,-4.163399,-2.860797
# 1,COM.NEXT.INNOVATION.TAKATAK,OTHERS,APPLICATIONS,SOCIAL,IN,ANDROID,VIVO,OTHERS,11,3.135494,0,7,0,1109,157,3,0.01910828,0,-20.72326584,-20.72326584,-20.72326584,-20.72326584,-3.792754,-3.032013
# 2,COM.NEXT.INNOVATION.TAKATAK,OTHERS,APPLICATIONS,SOCIAL,IN,ANDROID,XIAOMI,ENGLISH,9,3.850148,1,11,1,764,103,2,0.019417476,0,-20.72326584,-20.72326584,-20.72326584,-20.72326584,-3.975856,-3.014831
# 3,COM.NEXT.INNOVATION.TAKATAK,OTHERS,APPLICATIONS,SOCIAL,IN,ANDROID,VIVO,ENGLISH,30,1.94591,5,31,5,651,109,1,0.009174312,0,-20.72326584,-20.72326584,-20.72326584,-20.72326584,-3.68272,-3.230534
# 4,COM.NEXT.INNOVATION.TAKATAK,OTHERS,APPLICATIONS,SOCIAL,IN,ANDROID,XIAOMI,HINDI,9,3.688879,7,56,7,581,115,0,0,0,-20.72326584,-20.72326584,-20.72326584,-20.72326584,-3.834702,-3.210154
#
# 2021-10-27 12:04:12,829 ERROR - entry_point - Exception on /invocations [POST]
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_containers/_functions.py", line 93, in wrapper
#     return fn(*args, **kwargs)
#   File "/opt/ml/code/entry_point.py", line 34, in predict_fn
#     response = model.predict(request)
#   File "/miniconda3/lib/python3.7/site-packages/lightgbm/basic.py", line 3540, in predict
#     data_has_header, is_reshape)
#   File "/miniconda3/lib/python3.7/site-packages/lightgbm/basic.py", line 820, in predict
#     data = _data_from_pandas(data, None, None, self.pandas_categorical)[0]
#   File "/miniconda3/lib/python3.7/site-packages/lightgbm/basic.py", line 569, in _data_from_pandas
#     cat_cols = list(data.select_dtypes(include=['category']).columns)
#   File "/miniconda3/lib/python3.7/site-packages/pandas/core/frame.py", line 3442, in select_dtypes
#     include_these = Series(not bool(include), index=self.columns)
#   File "/miniconda3/lib/python3.7/site-packages/pandas/core/series.py", line 314, in __init__
#     data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#   File "/miniconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py", line 712, in sanitize_array
#     subarr = construct_1d_arraylike_from_scalar(value, len(index), dtype)
#   File "/miniconda3/lib/python3.7/site-packages/pandas/core/dtypes/cast.py", line 1233, in construct_1d_arraylike_from_scalar
#     subarr = np.empty(length, dtype=dtype)
# TypeError: Cannot interpret '<attribute 'dtype' of 'numpy.generic' objects>' as a data type
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.7/site-packages/flask/app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/miniconda3/lib/python3.7/site-packages/flask/app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/miniconda3/lib/python3.7/site-packages/flask/app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/miniconda3/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/miniconda3/lib/python3.7/site-packages/flask/app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/miniconda3/lib/python3.7/site-packages/flask/app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_containers/_transformer.py", line 200, in transform
#     self._model, request.content, request.content_type, request.accept
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_containers/_transformer.py", line 231, in _default_transform_fn
#     prediction = self._predict_fn(data, model)
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_containers/_functions.py", line 95, in wrapper
#     six.reraise(error_class, error_class(e), sys.exc_info()[2])
#   File "/miniconda3/lib/python3.7/site-packages/six.py", line 702, in reraise
#     raise value.with_traceback(tb)
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_containers/_functions.py", line 93, in wrapper
#     return fn(*args, **kwargs)
#   File "/opt/ml/code/entry_point.py", line 34, in predict_fn
#     response = model.predict(request)
#   File "/miniconda3/lib/python3.7/site-packages/lightgbm/basic.py", line 3540, in predict
#     data_has_header, is_reshape)
#   File "/miniconda3/lib/python3.7/site-packages/lightgbm/basic.py", line 820, in predict
#     data = _data_from_pandas(data, None, None, self.pandas_categorical)[0]
#   File "/miniconda3/lib/python3.7/site-packages/lightgbm/basic.py", line 569, in _data_from_pandas
#     cat_cols = list(data.select_dtypes(include=['category']).columns)
# 169.254.255.130 - - [27/Oct/2021:12:04:12 +0000] "POST /invocations HTTP/1.1" 500 290 "-" "Go-http-client/1.1"
#   File "/miniconda3/lib/python3.7/site-packages/pandas/core/frame.py", line 3442, in select_dtypes
#     include_these = Series(not bool(include), index=self.columns)
#   File "/miniconda3/lib/python3.7/site-packages/pandas/core/series.py", line 314, in __init__
#     data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#   File "/miniconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py", line 712, in sanitize_array
#     subarr = construct_1d_arraylike_from_scalar(value, len(index), dtype)
#   File "/miniconda3/lib/python3.7/site-packages/pandas/core/dtypes/cast.py", line 1233, in construct_1d_arraylike_from_scalar
#     subarr = np.empty(length, dtype=dtype)
# sagemaker_containers._errors.ClientError: Cannot interpret '<attribute 'dtype' of 'numpy.generic' objects>' as a data type
# 0,IN.MOHALLA.SHARECHAT,OTHERS,APPLICATIONS,SOCIAL,IN,ANDROID,VIVO,OTHERS,11,4.317488,3,5,3,1397,151,5,0.033112583,0,-20.72326584,-20.72326584,-20.72326584,-20.72326584,-4.163399,-2.860797
# 1,COM.NEXT.INNOVATION.TAKATAK,OTHERS,APPLICATIONS,SOCIAL,IN,ANDROID,VIVO,OTHERS,11,3.135494,0,7,0,1109,157,3,0.01910828,0,-20.72326584,-20.72326584,-20.72326584,-20.72326584,-3.792754,-3.032013
# 2,COM.NEXT.INNOVATION.TAKATAK,OTHERS,APPLICATIONS,SOCIAL,IN,ANDROID,XIAOMI,ENGLISH,9,3.850148,1,11,1,764,103,2,0.019417476,0,-20.72326584,-20.72326584,-20.72326584,-20.72326584,-3.975856,-3.014831
# 3,COM.NEXT.INNOVATION.TAKATAK,OTHERS,APPLICATIONS,SOCIAL,IN,ANDROID,VIVO,ENGLISH,30,1.94591,5,31,5,651,109,1,0.009174312,0,-20.72326584,-20.72326584,-20.72326584,-20.72326584,-3.68272,-3.230534
# 4,COM.NEXT.INNOVATION.TAKATAK,OTHERS,APPLICATIONS,SOCIAL,IN,ANDROID,XIAOMI,HINDI,9,3.688879,7,56,7,581,115,0,0,0,-20.72326584,-20.72326584,-20.72326584,-20.72326584,-3.834702,-3.210154
#
# 2021-10-27 12:04:12,850 ERROR - entry_point - Exception on /invocations [POST]
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_containers/_functions.py", line 93, in wrapper
#     return fn(*args, **kwargs)
#   File "/opt/ml/code/entry_point.py", line 34, in predict_fn
#     response = model.predict(request)
#   File "/miniconda3/lib/python3.7/site-packages/lightgbm/basic.py", line 3540, in predict
#     data_has_header, is_reshape)
#   File "/miniconda3/lib/python3.7/site-packages/lightgbm/basic.py", line 820, in predict
#     data = _data_from_pandas(data, None, None, self.pandas_categorical)[0]
#   File "/miniconda3/lib/python3.7/site-packages/lightgbm/basic.py", line 569, in _data_from_pandas
#     cat_cols = list(data.select_dtypes(include=['category']).columns)
#   File "/miniconda3/lib/python3.7/site-packages/pandas/core/frame.py", line 3442, in select_dtypes
#     include_these = Series(not bool(include), index=self.columns)
#   File "/miniconda3/lib/python3.7/site-packages/pandas/core/series.py", line 314, in __init__
#     data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#   File "/miniconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py", line 712, in sanitize_array
#     subarr = construct_1d_arraylike_from_scalar(value, len(index), dtype)
#   File "/miniconda3/lib/python3.7/site-packages/pandas/core/dtypes/cast.py", line 1233, in construct_1d_arraylike_from_scalar
#     subarr = np.empty(length, dtype=dtype)
# TypeError: Cannot interpret '<attribute 'dtype' of 'numpy.generic' objects>' as a data type
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.7/site-packages/flask/app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/miniconda3/lib/python3.7/site-packages/flask/app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/miniconda3/lib/python3.7/site-packages/flask/app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
# 169.254.255.130 - - [27/Oct/2021:12:04:12 +0000] "POST /invocations HTTP/1.1" 500 290 "-" "Go-http-client/1.1"
#   File "/miniconda3/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/miniconda3/lib/python3.7/site-packages/flask/app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/miniconda3/lib/python3.7/site-packages/flask/app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_containers/_transformer.py", line 200, in transform
#     self._model, request.content, request.content_type, request.accept
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_containers/_transformer.py", line 231, in _default_transform_fn
#     prediction = self._predict_fn(data, model)
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_containers/_functions.py", line 95, in wrapper
#     six.reraise(error_class, error_class(e), sys.exc_info()[2])
#   File "/miniconda3/lib/python3.7/site-packages/six.py", line 702, in reraise
#     raise value.with_traceback(tb)
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_containers/_functions.py", line 93, in wrapper
#     return fn(*args, **kwargs)
#   File "/opt/ml/code/entry_point.py", line 34, in predict_fn
#     response = model.predict(request)
#   File "/miniconda3/lib/python3.7/site-packages/lightgbm/basic.py", line 3540, in predict
#     data_has_header, is_reshape)
#   File "/miniconda3/lib/python3.7/site-packages/lightgbm/basic.py", line 820, in predict
#     data = _data_from_pandas(data, None, None, self.pandas_categorical)[0]
#   File "/miniconda3/lib/python3.7/site-packages/lightgbm/basic.py", line 569, in _data_from_pandas
#     cat_cols = list(data.select_dtypes(include=['category']).columns)
#   File "/miniconda3/lib/python3.7/site-packages/pandas/core/frame.py", line 3442, in select_dtypes
#     include_these = Series(not bool(include), index=self.columns)
#   File "/miniconda3/lib/python3.7/site-packages/pandas/core/series.py", line 314, in __init__
#     data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#   File "/miniconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py", line 712, in sanitize_array
#     subarr = construct_1d_arraylike_from_scalar(value, len(index), dtype)
#   File "/miniconda3/lib/python3.7/site-packages/pandas/core/dtypes/cast.py", line 1233, in construct_1d_arraylike_from_scalar
#     subarr = np.empty(length, dtype=dtype)
# sagemaker_containers._errors.ClientError: Cannot interpret '<attribute 'dtype' of 'numpy.generic' objects>' as a data type
# 2021-10-27 12:04:12,859 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# Looking in indexes: https://pypi.douban.com/simple
# Requirement already satisfied: joblib in /miniconda3/lib/python3.7/site-packages (1.1.0)
# Requirement already satisfied: pathlib in /miniconda3/lib/python3.7/site-packages (1.0.1)
# Requirement already satisfied: lightgbm in /miniconda3/lib/python3.7/site-packages (3.3.0)
# Requirement already satisfied: wheel in /miniconda3/lib/python3.7/site-packages (from lightgbm) (0.36.2)
# Requirement already satisfied: scipy in /miniconda3/lib/python3.7/site-packages (from lightgbm) (1.6.2)
# Requirement already satisfied: numpy in /miniconda3/lib/python3.7/site-packages (from lightgbm) (1.20.1)
# Requirement already satisfied: scikit-learn!=0.22.0 in /miniconda3/lib/python3.7/site-packages (from lightgbm) (0.20.0)
# /miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/externals/cloudpickle/cloudpickle.py:47: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp
# 0,IN.MOHALLA.SHARECHAT,OTHERS,APPLICATIONS,SOCIAL,IN,ANDROID,VIVO,OTHERS,11,4.317488,3,5,3,1397,151,5,0.033112583,0,-20.72326584,-20.72326584,-20.72326584,-20.72326584,-4.163399,-2.860797
# 1,COM.NEXT.INNOVATION.TAKATAK,OTHERS,APPLICATIONS,SOCIAL,IN,ANDROID,VIVO,OTHERS,11,3.135494,0,7,0,1109,157,3,0.01910828,0,-20.72326584,-20.72326584,-20.72326584,-20.72326584,-3.792754,-3.032013
# 2,COM.NEXT.INNOVATION.TAKATAK,OTHERS,APPLICATIONS,SOCIAL,IN,ANDROID,XIAOMI,ENGLISH,9,3.850148,1,11,1,764,103,2,0.019417476,0,-20.72326584,-20.72326584,-20.72326584,-20.72326584,-3.975856,-3.014831
# 3,COM.NEXT.INNOVATION.TAKATAK,OTHERS,APPLICATIONS,SOCIAL,IN,ANDROID,VIVO,ENGLISH,30,1.94591,5,31,5,651,109,1,0.009174312,0,-20.72326584,-20.72326584,-20.72326584,-20.72326584,-3.68272,-3.230534
# 4,COM.NEXT.INNOVATION.TAKATAK,OTHERS,APPLICATIONS,SOCIAL,IN,ANDROID,XIAOMI,HINDI,9,3.688879,7,56,7,581,115,0,0,0,-20.72326584,-20.72326584,-20.72326584,-20.72326584,-3.834702,-3.210154
#
# 2021-10-27 12:04:13,745 ERROR - entry_point - Exception on /invocations [POST]
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_containers/_functions.py", line 93, in wrapper
#     return fn(*args, **kwargs)
#   File "/opt/ml/code/entry_point.py", line 34, in predict_fn
#     response = model.predict(request)
#   File "/miniconda3/lib/python3.7/site-packages/lightgbm/basic.py", line 3540, in predict
#     data_has_header, is_reshape)
#   File "/miniconda3/lib/python3.7/site-packages/lightgbm/basic.py", line 820, in predict
#     data = _data_from_pandas(data, None, None, self.pandas_categorical)[0]
#   File "/miniconda3/lib/python3.7/site-packages/lightgbm/basic.py", line 569, in _data_from_pandas
#     cat_cols = list(data.select_dtypes(include=['category']).columns)
#   File "/miniconda3/lib/python3.7/site-packages/pandas/core/frame.py", line 3442, in select_dtypes
#     include_these = Series(not bool(include), index=self.columns)
#   File "/miniconda3/lib/python3.7/site-packages/pandas/core/series.py", line 314, in __init__
#     data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#   File "/miniconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py", line 712, in sanitize_array
#     subarr = construct_1d_arraylike_from_scalar(value, len(index), dtype)
#   File "/miniconda3/lib/python3.7/site-packages/pandas/core/dtypes/cast.py", line 1233, in construct_1d_arraylike_from_scalar
#     subarr = np.empty(length, dtype=dtype)
# TypeError: Cannot interpret '<attribute 'dtype' of 'numpy.generic' objects>' as a data type
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.7/site-packages/flask/app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/miniconda3/lib/python3.7/site-packages/flask/app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/miniconda3/lib/python3.7/site-packages/flask/app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/miniconda3/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/miniconda3/lib/python3.7/site-packages/flask/app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/miniconda3/lib/python3.7/site-packages/flask/app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_containers/_transformer.py", line 200, in transform
#     self._model, request.content, request.content_type, request.accept
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_containers/_transformer.py", line 231, in _default_transform_fn
#     prediction = self._predict_fn(data, model)
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_containers/_functions.py", line 95, in wrapper
#     six.reraise(error_class, error_class(e), sys.exc_info()[2])
#   File "/miniconda3/lib/python3.7/site-packages/six.py", line 702, in reraise
#     raise value.with_traceback(tb)
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_containers/_functions.py", line 93, in wrapper
#     return fn(*args, **kwargs)
#   File "/opt/ml/code/entry_point.py", line 34, in predict_fn
#     response = model.predict(request)
#   File "/miniconda3/lib/python3.7/site-packages/lightgbm/basic.py", line 3540, in predict
#     data_has_header, is_reshape)
#   File "/miniconda3/lib/python3.7/site-packages/lightgbm/basic.py", line 820, in predict
#     data = _data_from_pandas(data, None, None, self.pandas_categorical)[0]
#   File "/miniconda3/lib/python3.7/site-packages/lightgbm/basic.py", line 569, in _data_from_pandas
#     cat_cols = list(data.select_dtypes(include=['category']).columns)
#   File "/miniconda3/lib/python3.7/site-packages/pandas/core/frame.py", line 3442, in select_dtypes
#     include_these = Series(not bool(include), index=self.columns)
#   File "/miniconda3/lib/python3.7/site-packages/pandas/core/series.py", line 314, in __init__
#     data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#   File "/miniconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py", line 712, in sanitize_array
#     subarr = construct_1d_arraylike_from_scalar(value, len(index), dtype)
#   File "/miniconda3/lib/python3.7/site-packages/pandas/core/dtypes/cast.py", line 1233, in construct_1d_arraylike_from_scalar
#     subarr = np.empty(length, dtype=dtype)
# sagemaker_containers._errors.ClientError: Cannot interpret '<attribute 'dtype' of 'numpy.generic' objects>' as a data type
# 169.254.255.130 - - [27/Oct/2021:12:04:13 +0000] "POST /invocations HTTP/1.1" 500 290 "-" "Go-http-client/1.1"
# 0,IN.MOHALLA.SHARECHAT,OTHERS,APPLICATIONS,SOCIAL,IN,ANDROID,VIVO,OTHERS,11,4.317488,3,5,3,1397,151,5,0.033112583,0,-20.72326584,-20.72326584,-20.72326584,-20.72326584,-4.163399,-2.860797
# 1,COM.NEXT.INNOVATION.TAKATAK,OTHERS,APPLICATIONS,SOCIAL,IN,ANDROID,VIVO,OTHERS,11,3.135494,0,7,0,1109,157,3,0.01910828,0,-20.72326584,-20.72326584,-20.72326584,-20.72326584,-3.792754,-3.032013
# 2,COM.NEXT.INNOVATION.TAKATAK,OTHERS,APPLICATIONS,SOCIAL,IN,ANDROID,XIAOMI,ENGLISH,9,3.850148,1,11,1,764,103,2,0.019417476,0,-20.72326584,-20.72326584,-20.72326584,-20.72326584,-3.975856,-3.014831
# 3,COM.NEXT.INNOVATION.TAKATAK,OTHERS,APPLICATIONS,SOCIAL,IN,ANDROID,VIVO,ENGLISH,30,1.94591,5,31,5,651,109,1,0.009174312,0,-20.72326584,-20.72326584,-20.72326584,-20.72326584,-3.68272,-3.230534
# 4,COM.NEXT.INNOVATION.TAKATAK,OTHERS,APPLICATIONS,SOCIAL,IN,ANDROID,XIAOMI,HINDI,9,3.688879,7,56,7,581,115,0,0,0,-20.72326584,-20.72326584,-20.72326584,-20.72326584,-3.834702,-3.210154
#
# 2021-10-27 12:04:13,764 ERROR - entry_point - Exception on /invocations [POST]
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_containers/_functions.py", line 93, in wrapper
#     return fn(*args, **kwargs)
#   File "/opt/ml/code/entry_point.py", line 34, in predict_fn
#     response = model.predict(request)
#   File "/miniconda3/lib/python3.7/site-packages/lightgbm/basic.py", line 3540, in predict
#     data_has_header, is_reshape)
#   File "/miniconda3/lib/python3.7/site-packages/lightgbm/basic.py", line 820, in predict
#     data = _data_from_pandas(data, None, None, self.pandas_categorical)[0]
#   File "/miniconda3/lib/python3.7/site-packages/lightgbm/basic.py", line 569, in _data_from_pandas
#     cat_cols = list(data.select_dtypes(include=['category']).columns)
#   File "/miniconda3/lib/python3.7/site-packages/pandas/core/frame.py", line 3442, in select_dtypes
#     include_these = Series(not bool(include), index=self.columns)
#   File "/miniconda3/lib/python3.7/site-packages/pandas/core/series.py", line 314, in __init__
#     data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#   File "/miniconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py", line 712, in sanitize_array
#     subarr = construct_1d_arraylike_from_scalar(value, len(index), dtype)
#   File "/miniconda3/lib/python3.7/site-packages/pandas/core/dtypes/cast.py", line 1233, in construct_1d_arraylike_from_scalar
#     subarr = np.empty(length, dtype=dtype)
# TypeError: Cannot interpret '<attribute 'dtype' of 'numpy.generic' objects>' as a data type
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.7/site-packages/flask/app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/miniconda3/lib/python3.7/site-packages/flask/app.py", line 1951, in full_dispatch_request
# 169.254.255.130 - - [27/Oct/2021:12:04:13 +0000] "POST /invocations HTTP/1.1" 500 290 "-" "Go-http-client/1.1"
#     rv = self.handle_user_exception(e)
#   File "/miniconda3/lib/python3.7/site-packages/flask/app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/miniconda3/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/miniconda3/lib/python3.7/site-packages/flask/app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/miniconda3/lib/python3.7/site-packages/flask/app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_containers/_transformer.py", line 200, in transform
#     self._model, request.content, request.content_type, request.accept
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_containers/_transformer.py", line 231, in _default_transform_fn
#     prediction = self._predict_fn(data, model)
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_containers/_functions.py", line 95, in wrapper
#     six.reraise(error_class, error_class(e), sys.exc_info()[2])
#   File "/miniconda3/lib/python3.7/site-packages/six.py", line 702, in reraise
#     raise value.with_traceback(tb)
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_containers/_functions.py", line 93, in wrapper
#     return fn(*args, **kwargs)
#   File "/opt/ml/code/entry_point.py", line 34, in predict_fn
#     response = model.predict(request)
#   File "/miniconda3/lib/python3.7/site-packages/lightgbm/basic.py", line 3540, in predict
#     data_has_header, is_reshape)
#   File "/miniconda3/lib/python3.7/site-packages/lightgbm/basic.py", line 820, in predict
#     data = _data_from_pandas(data, None, None, self.pandas_categorical)[0]
#   File "/miniconda3/lib/python3.7/site-packages/lightgbm/basic.py", line 569, in _data_from_pandas
#     cat_cols = list(data.select_dtypes(include=['category']).columns)
#   File "/miniconda3/lib/python3.7/site-packages/pandas/core/frame.py", line 3442, in select_dtypes
#     include_these = Series(not bool(include), index=self.columns)
#   File "/miniconda3/lib/python3.7/site-packages/pandas/core/series.py", line 314, in __init__
#     data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#   File "/miniconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py", line 712, in sanitize_array
#     subarr = construct_1d_arraylike_from_scalar(value, len(index), dtype)
#   File "/miniconda3/lib/python3.7/site-packages/pandas/core/dtypes/cast.py", line 1233, in construct_1d_arraylike_from_scalar
#     subarr = np.empty(length, dtype=dtype)
# sagemaker_containers._errors.ClientError: Cannot interpret '<attribute 'dtype' of 'numpy.generic' objects>' as a data type
# 2021-10-27T12:04:12.804:[sagemaker logs]: MaxConcurrentTransforms=1, MaxPayloadInMB=10, BatchStrategy=MULTI_RECORD
# 2021-10-27T12:04:13.766:[sagemaker logs]: sagemaker-us-west-2-517141035927/dataset/v_data.csv: Bad HTTP status received from algorithm: 500
# 2021-10-27T12:04:13.767:[sagemaker logs]: sagemaker-us-west-2-517141035927/dataset/v_data.csv:
# 2021-10-27T12:04:13.767:[sagemaker logs]: sagemaker-us-west-2-517141035927/dataset/v_data.csv: Message:
# 2021-10-27T12:04:13.767:[sagemaker logs]: sagemaker-us-west-2-517141035927/dataset/v_data.csv: <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 3.2 Final//EN">
# 2021-10-27T12:04:13.767:[sagemaker logs]: sagemaker-us-west-2-517141035927/dataset/v_data.csv: <title>500 Internal Server Error</title>
# 2021-10-27T12:04:13.767:[sagemaker logs]: sagemaker-us-west-2-517141035927/dataset/v_data.csv: <h1>Internal Server Error</h1>
# 2021-10-27T12:04:13.767:[sagemaker logs]: sagemaker-us-west-2-517141035927/dataset/v_data.csv: <p>The server encountered an internal error and was unable to complete your request. Either the server is overloaded or there is an error in the application.</p>
# ---------------------------------------------------------------------------
# UnexpectedStatusException                 Traceback (most recent call last)
# <ipython-input-39-aa5cb67863f4> in <module>
#      35 #     join_source="Input",
#      36 #     output_filter="$[0 ,-1]",
# ---> 37     job_name=_job_name
#      38 )
#      39 lightgbm_transformer.wait()
#
# /opt/conda/lib/python3.7/site-packages/sagemaker/transformer.py in transform(self, data, data_type, content_type, compression_type, split_type, job_name, input_filter, output_filter, join_source, experiment_config, model_client_config, wait, logs)
#     223
#     224         if wait:
# --> 225             self.latest_transform_job.wait(logs=logs)
#     226
#     227     def delete_model(self):
#
# /opt/conda/lib/python3.7/site-packages/sagemaker/transformer.py in wait(self, logs)
#     419     def wait(self, logs=True):
#     420         if logs:
# --> 421             self.sagemaker_session.logs_for_transform_job(self.job_name, wait=True)
#     422         else:
#     423             self.sagemaker_session.wait_for_transform_job(self.job_name)
#
# /opt/conda/lib/python3.7/site-packages/sagemaker/session.py in logs_for_transform_job(self, job_name, wait, poll)
#    3895
#    3896         if wait:
# -> 3897             self._check_job_status(job_name, description, "TransformJobStatus")
#    3898             if dot:
#    3899                 print()
#
# /opt/conda/lib/python3.7/site-packages/sagemaker/session.py in _check_job_status(self, job, desc, status_key_name)
#    3282                 ),
#    3283                 allowed_statuses=["Completed", "Stopped"],
# -> 3284                 actual_status=status,
#    3285             )
#    3286
#
# UnexpectedStatusException: Error for Transform job lightgbm-batch-2021-10-27-11-59-34: Failed. Reason: AlgorithmError: See job logs for more information
